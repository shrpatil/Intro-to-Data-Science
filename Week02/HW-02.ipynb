# %% [markdown]
# ## Homework 2
#
# Please complete the functions below. These functions are for to simulate a fair and a biased die.
#
# The biased die has probabilities {0.25, 0.15, 0.15, 0.15, 0.15, 0.15}.
#
# Create 2 visualizations that shows outcomes of multiple rolls of a fair die and biased die.
# * Visualization for fair die
# * Visualization for biased die
#
# Repeat the process programatically and take the mean to create a new list. This list will be used to compare means of biased & unbiased dice.
# * Create a historgram showing means of biased & unbiased die
#
# * Use subcharts
# * All visualizations must have appropriate titles.
# * There are 3 visualization and expected format is
# ```
#  [V1] [V2]
#  [   V3  ]
#  ```

# %% [markdown]
# ## Simulation of fair die

# %%
import random 
import matplotlib.pyplot as plt

trial_count = 500

#definig a function to give fair die outcomes 

def fair_die_simulation(trials):
    options = [1,2,3,4,5,6]
    simulations = []
    
    for i in range (trials):
        n= random.choice(options)
        simulations.append(n)
    return simulations


#ploting the graph of outcome

f = plt.figure(figsize=(6,6))
plt.hist(fair_die_simulation(trial_count), color= '#a05195', alpha= 0.8)
plt.title("Visualization of fair die",fontsize =14,fontweight="bold")
plt.xlabel("Outcome", fontsize=13)
plt.ylabel("Frequency", fontsize=13)
plt.show()

# %% [markdown]
# ## Simulation of biased die

# %%
#definig a function to give biased die outcomes 

def biased_die_simuations(trials, weights=[0.25, 0.15, 0.15, 0.15, 0.15, 0.15]):
    options = [1,2,3,4,5,6]
    simulations = []
    for i in range (trials):
        n= random.choices(options,weights)
        simulations.extend(n)
    
    return simulations


#ploting the graph of outcomes 

f = plt.figure(figsize=(6,6))
plt.hist(biased_die_simuations(trial_count), color= '#a05195', alpha= 0.8)
plt.title('Visualization of biased die',fontsize =14,fontweight="bold")
plt.xlabel("Outcome", fontsize=13)
plt.ylabel("Frequency", fontsize=13)
plt.show()

# %% [markdown]
# ## Comparison of fair and biased dice means

# %%
#calculating the mean of 1000 outcomes of both the dice

import numpy as np

biased_mean_list=[]
unbiased_mean_list=[]

for i in range(1000):
    
    biased = biased_die_simuations(trial_count)
    biased_mean_list.append(np.mean(biased))
    
    fair = fair_die_simulation(trial_count)
    unbiased_mean_list.append(np.mean(fair))
 

 #Ploting the graph 
f = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.title('Biased die Mean',fontsize =14,fontweight="bold")
plt.hist(biased_mean_list, bins=30,color='#003f5c',alpha=.7)
plt.xlabel("Mean", fontsize=13)
plt.ylabel("Frequency", fontsize=13)

plt.subplot(2,2,2)
plt.title('Unbiased die Mean',fontsize =14,fontweight="bold")
plt.hist(unbiased_mean_list, bins=30, color='#ffa600', alpha=.7)
plt.xlabel("Mean", fontsize=13)
plt.ylabel("Frequency", fontsize=13)

plt.subplot(2,2,(3,4))
arr1 = plt.hist(biased_mean_list,color='#003f5c',alpha=.6, bins=40)
arr2 = plt.hist(unbiased_mean_list, color='#ffa600', alpha=.6, bins=40)
plt.title('Comparing Means',fontsize =14,fontweight="bold")
plt.xlabel("Mean", fontsize=13)
plt.ylabel("Frequency", fontsize=13)
plt.legend([arr1,arr2],['Biased_mean','Unbiased_mean'])
plt.tight_layout()
plt.show()
# Out:
# No handles with labels found to put in legend.
